# %%
using Plots
# x and y given as arrays
plot(sin)
# Out:
#     <div id="128e7196-ecd8-43dd-a9ee-01fec1d9abe5" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('128e7196-ecd8-43dd-a9ee-01fec1d9abe5', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.9934383202099738
#         },
#         "yaxis": "y",
#         "x": [
#             -5.0,
#             -4.98372363496702,
#             -4.9674472699340395,
#             -4.951170904901059,
#             -4.934894539868079,
#             -4.859645291410925,
#             -4.784396042953771,
#             -4.746771418725194,
#             -4.709146794496617,
#             -4.671522170268041,
#             -4.633897546039464,
#             -4.596272921810886,
# ...
